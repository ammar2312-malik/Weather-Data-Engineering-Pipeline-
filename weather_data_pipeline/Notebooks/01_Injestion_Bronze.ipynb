# %%
import requests 
import json

latitude = 23.0225
longitude = 72.5714

url = (
    f"https://api.open-meteo.com/v1/forecast?"
    f"latitude={latitude}"
    f"&longitude={longitude}"
    f"&hourly=temperature_2m,relative_humidity_2m"
    f"&past_days=7"
)
response = requests.get(url)
data = response.json()

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "latitude": 23.022846,
#   "longitude": 72.60188,
#   "generationtime_ms": 0.05316734313964844,
#   "utc_offset_seconds": 0,
#   "timezone": "GMT",
#   "timezone_abbreviation": "GMT",
#   "elevation": 53.0,
#   "hourly_units": {
#     "time": "iso8601",
#     "temperature_2m": "\u00b0C",
#     "relative_humidity_2m": "%"
#   },
#   "hourly": {
#     "time": [
#       "2026-06-09T00:00",
#       "2026-06-09T01:00",
#       "2026-06-09T02:00",
#       "2026-06-09T03:00",
#       "2026-06-09T04:00",
#       "2026-06-09T05:00",
#       "2026-06-09T06:00",
#       "2026-06-09T07:00",
#       "2026-06-09T08:00",
#       "2026-06-09T09:00",
#       "2026-06-09T10:00",
#       "2026-06-09T11:00",
#       "2026-06-09T12:00",
#       "2026-06-09T13:00",
#       "2026-06-09T14:00",
#       "2026-06-09T15:00",
#       "2026-06-09T16:00",
#       "2026-06-09T17:00",
#       "2026-06-09T18:00",
#       "2026-06-09T19:00",
#       "2026-06-09T20:00",
#       "2026-06-09T21:00",
# ...

# %% [markdown]
# ### Save Raw Data to Bronze ###

# %%
with open("../Data/01_Bronze/weather_hourly_raw.json", "w") as f: 
    json.dump(data, f, indent=4)

# %%
len(data["hourly"]["time"])
# Out:
# 336

# %%
print(data["hourly"]["time"][0])
print(data["hourly"]["time"][-1])
# Out:
# 2026-06-09T00:00
# 2026-06-22T23:00

# %%
len(data["hourly"]["relative_humidity_2m"])
# Out:
# 336

# %%
print(data.keys())
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units', 'hourly'])

# %%
print(data["hourly"].keys())
# Out:
# dict_keys(['time', 'temperature_2m', 'relative_humidity_2m'])
